# %% [markdown]
# # 4. Netflix Titles Dataset
# **Objective: Explore the distribution of Netflix titles by genre, country, and release year.**

# %%
# import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
netflix = pd.read_csv('netflix_titles.csv')
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# Get the columns of series produces in India
india = netflix[netflix["country"]=="India"][["title","director"]]
india
# Out:
#                               title                 director
# 4                      Kota Factory                      NaN
# 24                            Jeans               S. Shankar
# 39                     Chhota Bheem                      NaN
# 50                    Dharmakshetra                      NaN
# 66    Raja Rasoi Aur Anya Kahaniyan                      NaN
# ...                             ...                      ...
# 8773            Yanda Kartavya Aahe             Kedar Shinde
# 8775                Yeh Meri Family                      NaN
# 8798                       Zed Plus  Chandra Prakash Dwivedi
# 8799                          Zenda           Avadhoot Gupte
# 8806                         Zubaan              Mozez Singh
#
# [972 rows x 2 columns]

# %%
# Get the tv shows released  in the year 2020
netflix[(netflix["listed_in"]== "TV Shows" ) & (netflix["release_year"]==2020)]
# Out:
#      show_id     type                      title  \
# 148     s149  TV Show                 HQ Barbers
# 2877   s2878  TV Show  Six Windows in the Desert
#
#                                                director  \
# 148                                     Gerhard Mostert
# 2877  Ali Kalthami, Meshal Aljaser, Faris Godus, Moh...
#
#                                                    cast       country  \
# 148   Hakeem Kae-Kazim, Chioma Omeruah, Orukotan Ade...           NaN
# 2877  Moayad Alnefaie, Mohammed Alhamdan, Citi Bet B...  Saudi Arabia
#
#              date_added  release_year rating  duration listed_in  \
# 148   September 1, 2021          2020  TV-14  1 Season  TV Shows
# 2877  February 27, 2020          2020  TV-14  1 Season  TV Shows
#
#                                             description
# 148   When a family run barber shop in the heart of ...
# 2877  From a theatre play to the aftermath of a plan...

# %%
# using pivot to reshape data
pivot = netflix.pivot_table(columns="rating", index="country" ,values="title", aggfunc="count")
pivot
# Out:
# rating                                              66 min  74 min  84 min  \
# country
# , France, Algeria                                      NaN     NaN     NaN
# , South Korea                                          NaN     NaN     NaN
# Argentina                                              NaN     NaN     NaN
# Argentina, Brazil, France, Poland, Germany, Den...     NaN     NaN     NaN
# Argentina, Chile                                       NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Venezuela                                              NaN     NaN     NaN
# Venezuela, Colombia                                    NaN     NaN     NaN
# Vietnam                                                NaN     NaN     NaN
# West Germany                                           NaN     NaN     NaN
# Zimbabwe                                               NaN     NaN     NaN
#
# ...

# %%
#Number of titles added per release year 

#aggfunc is used to aggregate data when multiple rows fall in same rows+column group 
pivot2 = netflix.pivot_table(index="release_year", columns="rating",values="title",aggfunc="count") 
pivot2
# Out:
# rating        66 min  74 min  84 min    G  NC-17   NR    PG  PG-13     R  \
# release_year
# 1925             NaN     NaN     NaN  NaN    NaN  NaN   NaN    NaN   NaN
# 1942             NaN     NaN     NaN  NaN    NaN  NaN   NaN    NaN   NaN
# 1943             NaN     NaN     NaN  NaN    NaN  NaN   NaN    NaN   NaN
# 1944             NaN     NaN     NaN  NaN    NaN  NaN   NaN    NaN   NaN
# 1945             NaN     NaN     NaN  NaN    NaN  NaN   NaN    NaN   NaN
# ...              ...     ...     ...  ...    ...  ...   ...    ...   ...
# 2017             NaN     1.0     NaN  1.0    NaN  2.0  15.0   32.0  73.0
# 2018             NaN     NaN     NaN  2.0    1.0  1.0  31.0   30.0  52.0
# 2019             NaN     NaN     NaN  1.0    NaN  NaN  12.0   19.0  39.0
# 2020             NaN     NaN     NaN  1.0    NaN  NaN  15.0   21.0  48.0
# 2021             NaN     NaN     NaN  NaN    NaN  NaN  11.0   14.0  21.0
#
# rating        TV-14  TV-G  TV-MA  TV-PG  TV-Y  TV-Y7  TV-Y7-FV  UR
# ...

# %%
#getting all the different rating
netflix["rating"].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
# Clleaning the rating column (removing the unnecessary timing)
valid_ratings = ['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
       'TV-G', 'G', 'NC-17' 'NR', 'TV-Y7-FV', 'UR']

netflix["cleaned_ratings"]= netflix["rating"].where(netflix["rating"].isin(valid_ratings),np.nan)

# %%
# Add a column to explain what the rating means 
conditions = [
    netflix["rating"]== "TV-MA",
    netflix["rating"]== "TV-14",
    netflix["rating"]== "TV-PG",
    netflix["rating"]== "PG-13",
    netflix["rating"]== "PG",
    netflix["rating"]== "TV-Y",
    netflix["rating"]== "TV-Y7",
    netflix["rating"]== "R",
    netflix["rating"]== "TV-G",
    netflix["rating"]== "G",
    netflix["rating"]== "NC-17",
    netflix["rating"]== "NR",
    netflix["rating"]== "TV-YZ-FV",
    netflix["rating"]== "UR",
]

choices = ["Matured Audience ONly - Adults only",
           "Parents Strongly Cautonied -14+",
           "Parental Guidance Suggested",
           "Parents Strongly Cautonied -13+",
           "Parental Guidance",
           "Suitable for all Children ",
           "Age 7 and Up",
           "Restricted -17 + only with adult",
           "Television general auidiance - Suitable for all",
           "General Audiance - All ages",
           "Adults Only -17+",
           "Not Rated",
           "age above seven but fantasy violence",
           "Unrated"
           ]

netflix["rating explained"] = np.select(conditions,choices,default="No description available")
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# getting movies directed by a particular director
netflix[netflix["director"]=="Kirsten Johnson"][["title","description"]]
# Out:
#                   title                                        description
# 0  Dick Johnson Is Dead  As her father nears the end of his life, filmm...

# %%
# getting all shows in which Ahsaas Channa is casted
netflix[netflix["cast"].str.contains("Ahsaas Channa")]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 # getting all shows in which Ahsaas Channa is casted
# ----> 2 netflix[netflix["cast"].str.contains("Ahsaas Channa")]
#
# File c:\Users\Gayatri\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\frame.py:3751, in DataFrame.__getitem__(self, key)
#    3748     return self.where(key)
#    3750 # Do we have a (boolean) 1d indexer?
# -> 3751 if com.is_bool_indexer(key):
#    3752     return self._getitem_bool_array(key)
#    3754 # We are left with two options: a single key, and a collection of keys,
#    3755 # We interpret tuples as collections only for non-MultiIndex
#
# File c:\Users\Gayatri\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\common.py:134, in is_bool_indexer(key)
#     130     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
# ...
